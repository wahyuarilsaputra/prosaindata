# %%
import psycopg2
conn = psycopg2.connect(
    database="prosaindata{200411100055}",
    user = "postgres",
    password = "root",
    host = "localhost",
    prot = "5432"
)
cur = conn.cursor()
cur.execute("SELECT * FROM data_iris")
rows = cur.fetchall()
for row in rows:
  print(roW)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-2-72ca77387866> in <module>
#       1 import psycopg2
# ----> 2 conn = psycopg2.connect(
#       3     database="prosaindata{200411100055}",
#       4     user = "postgres",
#       5     password = "root",
#
# /usr/local/lib/python3.8/dist-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119         kwasync['async_'] = kwargs.pop('async_')
#     120
# --> 121     dsn = _ext.make_dsn(dsn, **kwargs)
#     122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# /usr/local/lib/python3.8/dist-packages/psycopg2/extensions.py in make_dsn(dsn, **kwargs)
#     165
#     166     # verify that the returned dsn is valid
# --> 167     parse_dsn(dsn)
#     168
#     169     return dsn
#
# ...
