# %% [markdown]
# ## Tugas 1 : Crawling Data

# %% [markdown]
# #crawling data Twitter

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.6.2.20230320-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from snscrape) (2.27.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from snscrape) (3.12.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from snscrape) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->snscrape) (2.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (2.0.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.6.2.20230320

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
tweet_list = []

# %%
#mangambil data twitter dengan TwitterSearchScrapper dan meletakan dalam array
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Ganjar since:2022-01-01 until:2023-02-20').get_items()):
  if i>500:
    break
  tweet_list.append([tweet.user.username,tweet.content,tweet.user.location])
# Out:
# ERROR:snscrape.base:Error retrieving https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&include_ext_is_blue_verified=1&include_ext_verified_type=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_ext_views=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=Ganjar+since%3A2022-01-01+until%3A2023-02-20&tweet_search_mode=live&count=20&query_source=spelling_expansion_revert_click&pc=1&spelling_corrections=1&include_ext_edit_control=true&ext=mediaStats%2ChighlightedLabel%2ChasNftAvatar%2CvoiceInfo%2Cenrichments%2CsuperFollowMetadata%2CunmentionInfo%2CeditControl%2Ccollab_control%2Cvibe: blocked (403)
# CRITICAL:snscrape.base:4 requests to https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&include_ext_is_blue_verified=1&include_ext_verified_type=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_ext_views=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=Ganjar+since%3A2022-01-01+until%3A2023-02-20&tweet_search_mode=live&count=20&query_source=spelling_expansion_revert_click&pc=1&spelling_corrections=1&include_ext_edit_control=true&ext=mediaStats%2ChighlightedLabel%2ChasNftAvatar%2CvoiceInfo%2Cenrichments%2CsuperFollowMetadata%2CunmentionInfo%2CeditControl%2Ccollab_control%2Cvibe failed, giving up.
# CRITICAL:snscrape.base:Errors: blocked (403), blocked (403), blocked (403), blocked (403)
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-5-06670b9730c1> in <cell line: 2>()
#       1 #mangambil data twitter dengan TwitterSearchScrapper dan meletakan dalam array
# ----> 2 for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Ganjar since:2022-01-01 until:2023-02-20').get_items()):
#       3   if i>500:
#       4     break
#       5   tweet_list.append([tweet.user.username,tweet.content,tweet.user.location])
#
# /usr/local/lib/python3.10/dist-packages/snscrape/modules/twitter.py in get_items(self)
#    1659                 del params['cursor']
#    1660
# -> 1661                 for obj in self._iter_api_data('https://api.twitter.com/2/search/adaptive.json', _TwitterAPIType.V2, params, paginationParams, cursor = self._cursor):
#    1662                         yield from self._v2_timeline_instructions_to_tweets_or_users(obj)
#    1663
#
# /usr/local/lib/python3.10/dist-packages/snscrape/modules/twitter.py in _iter_api_data(self, endpoint, apiType, params, paginationParams, cursor, direction)
#     759                 while True:
#     760                         _logger.info(f'Retrieving scroll page {cursor}')
# --> 761                         obj = self._get_api_data(endpoint, apiType, reqParams)
#     762                         yield obj
#     763
#
# /usr/local/lib/python3.10/dist-packages/snscrape/modules/twitter.py in _get_api_data(self, endpoint, apiType, params)
#     725                 if apiType is _TwitterAPIType.GRAPHQL:
#     726                         params = urllib.parse.urlencode({k: json.dumps(v, separators = (',', ':')) for k, v in params.items()}, quote_via = urllib.parse.quote)
# --> 727                 r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = self._check_api_response)
#     728                 try:
#     729                         obj = r.json()
#
# /usr/local/lib/python3.10/dist-packages/snscrape/base.py in _get(self, *args, **kwargs)
#     249
#     250         def _get(self, *args, **kwargs):
# --> 251                 return self._request('GET', *args, **kwargs)
#     252
#     253         def _post(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/snscrape/base.py in _request(self, method, url, params, data, headers, timeout, responseOkCallback, allowRedirects, proxies)
#     245                         _logger.fatal(msg)
#     246                         _logger.fatal(f'Errors: {", ".join(errors)}')
# --> 247                         raise ScraperException(msg)
#     248                 raise RuntimeError('Reached unreachable code')
#     249
#
# ScraperException: 4 requests to https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&include_ext_is_blue_verified=1&include_ext_verified_type=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_ext_views=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=Ganjar+since%3A2022-01-01+until%3A2023-02-20&tweet_search_mode=live&count=20&query_source=spelling_expansion_revert_click&pc=1&spelling_corrections=1&include_ext_edit_control=true&ext=mediaStats%2ChighlightedLabel%2ChasNftAvatar%2CvoiceInfo%2Cenrichments%2CsuperFollowMetadata%2CunmentionInfo%2CeditControl%2Ccollab_control%2Cvibe failed, giving up.

# %%
frame_tweet = pd.DataFrame(tweet_list,columns =['Username','Konten','Lokasi'])
frame_tweet
# Out:
#             Username                                             Konten  \
# 0      Krisna0902022  @aniesbaswedan @NasDem @PDemokrat @PKSejahtera...
# 1     ArmChristian72  @Yuyem93 Kali ini sy sepakat dg Refly Harun bh...
# 2    BantenNews_coid  Tak Ada Anies dan Ganjar, Ini Nama-nama Capres...
# 3      teguh_hteguh2  @skyeagle805 @ganjarpranowo @gibran_tweet Pa G...
# 4            jpnncom  Makin Masif Memperkenalkan Ganjar Pranowo, Sag...
# ..               ...                                                ...
# 496  adriana61590726  Mantap kali pembangunan di Indonesia  Terima k...
# 497  catatankaqihati  Ganjar Pranowo Luncurkan Program KANCING MERAH...
# 498       aleyna_akl  Presiden  Ganjar menjadikan Indonesia lebih ba...
# 499  RulliferGonzalv  Gas terus  Ganjar bangun Infrastruktur  Dengan...
# 500  joubert_cardoso  Tetap Semangat, jangan lupa ngopi  Pak  Ganjar...
#
#                   Lokasi
# 0
# 1
# 2    Kota Serang, Banten
# 3       Bekasi-indonesia
# 4              Indonesia
# ..                   ...
# 496
# 497            Indonesia
# 498
# 499
# 500
#
# [501 rows x 3 columns]

# %%
frame_tweet.to_csv('datatwt.csv',sep=',',index=False)

# %% [markdown]
# #Crawling data Berita Online

# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (4.6.3)

# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
pencarian = 'snbp'
cari = pencarian.replace(' ','+')
tglAwal = '18/01/2022'
tglAkhir = '18/02/2023'
header={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'
}
berita_list = []
for halaman in range(1):
  url = f'https://www.detik.com/search/searchall?query={cari}&sortby=time&fromdatex={tglAwal}&todatex={tglAkhir}&page={halaman}'
  #mengambil data dari detik.com
  req = requests.get(url,header)
  soup = BeautifulSoup(req.text,'lxml')
  listberita = soup.find('div',class_='list media_rows list-berita')
  artikel = listberita.find_all('article')
  for x in artikel:
    url2 = x.find('a')['href']
    judul = x.find('a').find('h2').text
    #mengambil data dari setiap konten
    urlkonten = requests.get(url2,header)
    soupkonten = BeautifulSoup(urlkonten.text,'lxml')
    konten = soupkonten.find_all('div',class_='detail__body-text itp_bodycontent')
    for x in konten:
      isi = x.find_all('p')
      y = [y.text for y in isi]
      fixkonten = ''.join(y).replace('\n','').replace('ADVERTISEMENT','').replace('SCROLL TO RESUME CONTENT','')
      berita_list.append([judul,fixkonten])

# %%
frame_berita = pd.DataFrame(berita_list,columns =['Judul','Isi'])
frame_berita
# Out:
#                                                Judul  \
# 0  Daya Tampung Unsoed 2023 Jalur SNBP-SNBT-SPMB ...
# 1  Cara Daftar Akun SNPMB buat Ikut SNBT 2023, Tu...
# 2  Cara Daftar KIP Kuliah untuk SNBP 2023, Jangan...
# 3     UI: Tidak Ada Penjatahan Kuota Per SMA di SNBP
# 4  Apakah Siswa Boleh Minta Indeks Sekolah untuk ...
# 5  10 Prodi dengan Daya Tampung Tertinggi-Terenda...
# 6  14 Jenis Beasiswa ITS untuk Maba ITS, Ini Rinc...
# 7  Cek Daftar Prodi Unpad dengan Daya Tampung Ter...
# 8  Jadwal Lengkap Pendaftaran KIP Kuliah untuk SN...
#
#                                                  Isi
# 0  Universitas Jenderal Soedirman (Unsoed) pada t...
# 1  Detikers yang ingin mengikuti jalur masuk PTN ...
# 2  Pendaftaran akun Kartu Indonesia Pintar (KIP) ...
# 3  Universitas Indonesia (UI) tidak melakukan pen...
# 4  Salah satu faktor yang paling krusial dan mene...
# 5  Universitas Hasanuddin (Unhas) pada Seleksi Na...
# 6  Pihak Institut Teknologi Sepuluh Nopember (ITS...
# 7  Seleksi Nasional Berdasarkan Prestasi (SNBP) t...
# 8  Pendaftaran Kartu Indonesia Pintar (KIP) Kulia...

# %%
frame_berita.to_csv('databerita.csv',sep=',',index=False)

# %% [markdown]
# #Crawling Website PTA

# %%
header={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'
}
#Teknik_informatika = 10
pta_list = []
for halaman_prodi in range(1,5):
  for halaman in range(1,2):
    url = f"https://pta.trunojoyo.ac.id/c_search/byprod/{halaman_prodi}/{str(halaman+1)}"
    req = requests.get(url)
    soup = BeautifulSoup(req.text, 'lxml')
    prodi = soup.find('h2').text.replace('Journal','')
    list_ = soup.find('div', {'id':'content_journal'})

    for pta in list_.findAll('li',{'data-cat':'#luxury'}):
      Nama = pta.span.text.strip('\n').replace('Penulis : ', '')
      link = pta.find('a', 'gray button')['href']
      req = requests.get(link)
      soup2 = BeautifulSoup(req.text, 'lxml')
      judul = pta.a.text.strip('\n').replace('\r','').replace('\n','')
      abstrak = soup2.find('p', {'align':'justify'}).text.replace('ABSTRAK','').replace('\r','').replace('\n','').replace('\t','')
    
      NIM = link.replace('https://pta.trunojoyo.ac.id/welcome/detail/', '')

      pta_list.append([ NIM,Nama,judul,abstrak,prodi])

# %%
frame_pta = pd.DataFrame(pta_list, columns=['NIM','Nama','Judul','Abstrak','Prodi'])
frame_pta
# Out:
#              NIM                        Nama  \
# 0   070111100093          Andri Eka Sugiarto
# 1   080111100029           Agung Saiful Anam
# 2   080111100011              Adityo Nugroho
# 3   080111100023  Yuliano Orgianus Landowero
# 4   080111100007     NUR INDAH FENY SURYANTI
# 5   080331100012           Eko Suryo Firdaus
# 6   080331100057       Nor Wulan Purnamasari
# 7   080331100069              Ratih Eka Sari
# 8   080331100022                Ifan Fahrezi
# 9   080331100019          Anik Puji Hastutik
# 10  080321100009             Yunita Kurniati
# 11  080321100025                  samsiyatun
# 12  090321100002               NOR QOMARIYAH
# 13  090321100019              Izzatul Millah
# 14  090321100001                     RUSMINI
# 15  080311100028                      Mahfut
# 16  080311100006          Lailatul Qadariyah
# 17  080311100001                Imam Muchlis
# 18  080311100003         Oktavian Ari Husada
# 19  090311100009               Liya Andriani
#
#                                                 Judul  \
# 0   TELAAH KRITIS TENTANGPEMBERITAAN MEDIA MASSA T...
# 1   PELAKSANAAN PENDAFTARAN TANAH UNTUK PERTAMA KA...
# 2   TRANSAKSI JUAL BELI MELALUI INTERNET PERSPEKTI...
# 3   PELAKSANAAN MORATORIUM PENGIRIMAN TENAGA KERJA...
# 4   ASPEK PIDANA DALAM JUAL BELI OLI BEKAS KAPAL D...
# 5   Formulasi Yogurt Sinbiotik Susu Kecipir dan Mu...
# 6   PENGARUH LABEL HALAL PADA KEMASANTERHADAP KEPU...
# 7   Analisis Keseimbangan Lintasan Produksi Fillet...
# 8   Analisis Finansial Pembuatan Minyak Atsiri Tem...
# 9   Analisis Metode Kerja Pada Bagian Trimming (St...
# 10  PENGARUH BAURAN PEMASARAN TERHADAP KEPUTUSAN P...
# 11  PERAN KELOMPOK TANI DEWI RATIH DALAM PENINGKAT...
# 12  PENGEMBANGAN AGROINDUSTRI BERBASIS KOMODITAS U...
# 13  STRATEGI PENINGKATAN PRODUKTIVITAS USAHATANI B...
# 14  Analisis Faktor-faktor Yang Mempengaruhi Peril...
# 15  PERTUMBUHAN STEK SULUR BUAH CABE JAMU(Piper re...
# 16  KAJIAN HUBUNGAN UNSUR HARA MIKRO (Fe, Cu, Mn) ...
# 17  Agroekologi Cabe Jamu (Piper retrofractum Vahl...
# 18  Hubungan Kadar Air, Kandungan N, dan Bahan org...
# 19  PENGARUH JENIS TANAH TERHADAP KADAR PIPERIN PA...
#
#                                               Abstrak  \
# 0   Jaminan akan kemerdekaan dan kebebasan pers di...
# 1   Pendaftaran tanah untuk pertama kali bertujuan...
# 2   Salah satu bentuk kemajuan teknologi adalah ju...
# 3   Pelaksanaan terhadap kebijakan moratorium yang...
# 4   Oli bekas kapal merupakan oli sisa yang dihasi...
# 5   Formulasi yogurt sinbiotik susu kecipir dan mu...
# 6   Salah satu usaha dari produsen untuk meyakinka...
# 7   Keseimbangan lintasan merupakan keseimbangan p...
# 8   Produk tembakau yang selama ini dikenal hanya ...
# 9   Penerapan sistem semi-mekanik berpengaruh terh...
# 10  Perkembangan dunia bisnis saat ini tumbuh deng...
# 11  Seiring dengan perkembangan pembangunan pertan...
# 12  Penelitian ini dilakukan di Kawasan Utara Kabu...
# 13  Produktivitas bawang merah di daerah penelitia...
# 14  Penelitian ini dilakukan di Pasar Ki Lemah Duw...
# 15  Penanaman stek cabe jamu secara langsung di la...
# 16  Cabe jamu (Piper retrofractum Vahl) merupakan ...
# 17  Cabe Jamu atau cabe jawa (Piper retrofractum V...
# 18  Cabe Jamu atau cabe jawa (Piper retrofractum V...
# 19  Cabe Jawa (Piper retrofractum Vahl) tergolong ...
#
#                                     Prodi
# 0                      Jurusan Ilmu Hukum
# 1                      Jurusan Ilmu Hukum
# 2                      Jurusan Ilmu Hukum
# 3                      Jurusan Ilmu Hukum
# 4                      Jurusan Ilmu Hukum
# 5    Jurusan Teknologi Industri Pertanian
# 6    Jurusan Teknologi Industri Pertanian
# 7    Jurusan Teknologi Industri Pertanian
# 8    Jurusan Teknologi Industri Pertanian
# 9    Jurusan Teknologi Industri Pertanian
# 10                     Jurusan Agribisnis
# 11                     Jurusan Agribisnis
# 12                     Jurusan Agribisnis
# 13                     Jurusan Agribisnis
# 14                     Jurusan Agribisnis
# 15                  Jurusan Agroteknologi
# 16                  Jurusan Agroteknologi
# 17                  Jurusan Agroteknologi
# 18                  Jurusan Agroteknologi
# 19                  Jurusan Agroteknologi

# %%
frame_pta.to_csv('datapta.csv',sep=',',index=False)
