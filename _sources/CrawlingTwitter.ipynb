# %% [markdown]
# ## Tugas 1 : Crawling Data Twitter

# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.5.0.20230113-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.5.0.20230113

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
#manampung data dalam array
tweet_list = []

# %%
#mangambil data twitter dengan TwitterSearchScrapper dan meletakan dalam array
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Cak Imin since:2018-01-01 until:2023-02-20').get_items()):
  if i>1500:
    break
  tweet_list.append([tweet.user.username,tweet.content,tweet.user.location])
# Out:
# <ipython-input-4-e0426a6a3906>:5: FutureWarning: content is deprecated, use rawContent instead
#   tweet_list.append([tweet.user.username,tweet.content,tweet.user.location])

# %%
frame_tweet = pd.DataFrame(tweet_list,columns =['Username','Konten','Lokasi'])
frame_tweet
# Out:
#              Username                                             Konten  \
# 0            arek0218  Peringati Isra Miraj, Cak Imin Doakan Umat Isl...
# 1       AndiniSesilia  “Sampai sekarang Prabowo sendiri masih belum t...
# 2     IsmailMangngaga  Peringati Isra Miraj, Cak Imin Doakan Umat Isl...
# 3     Emerald72063957  @detikcom Semoga segera deklarasi, kalau masih...
# 4     ahmadhellishfau  #JokowiCakImin #JoinKepri2019 #NasionalisRelig...
# ...               ...                                                ...
# 1496    achmadsarnuji               Terimakasih Gus Muhaimin\n# Cak Imin
# 1497    OposisiCerdas  Sulit Raih Kemenangan, Prabowo Sedang Kalkulas...
# 1498        NdaraKaji  @txtdrMagelang @iya_hanaa Admin numpak VX, Cak...
# 1499        YandraD31  @AndiSinulingga Bertempur lah Dan kita saksika...
# 1500     tio_richardo      Tiati ndan nanti diserang bajer Cak Imin 🤭🤭🤣🤣
#
#                            Lokasi
# 0
# 1
# 2     Sulawesi Selatan, Indonesia
# 3
# 4
# ...                           ...
# 1496
# 1497
# 1498  Denpasar Selatan, Indonesia
# 1499
# 1500
#
# [1501 rows x 3 columns]

# %%
frame_tweet.to_csv('crawling cak imin.csv',sep=",")
